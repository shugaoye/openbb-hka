# %%
import akshare as ak
from mysharelib.tools import normalize_symbol
from core.config import config
from fin_data.profile import get_quote, get_price

# %%
data=get_quote("06823,600104")

# %%
# For pandas DataFrame - in-place modification
data = get_price("06823")
#data.set_index('item', inplace=True)

# %%
data.set_index('item', inplace=True)

# %%
data.loc[["代码"]]="06823.HK"

# %%
data
# Out:
#                         value
# item
# 代码                   06823.HK
# 52周最高                   12.95
# 流通股                7579776147
# 最高                      11.78
# 流通值             88986571966.0
# 最小交易单位                   1000
# 涨跌                       0.12
# 每股收益                   0.6794
# 昨收                      11.62
# 成交量                   3184849
# 周转率                      0.04
# 52周最低                    9.39
# 名称                    香港电讯-SS
# 交易所                        HK
# 市盈率(动)                21.4943
# 基金份额/总股本           7579776147
# 均价                    11.7239
# 涨幅                       1.03
# 市销率                     2.568
# 振幅                       1.72
# 现价                      11.74
# 今年以来涨幅                  30.82
# 发行日期      2011-11-29 00:00:00
# 最低                      11.58
# 资产净值/总市值        88986571966.0
# 股息(TTM)                 0.797
# 股息率(TTM)                 6.79
# 货币                        HKD
# 每股净资产                  4.7895
# 市盈率(静)                17.5516
# ...

# %%
data.T[["代码", "名称", "现价", "52周最低", "52周最高", "成交量", "股息率(TTM)", "股息(TTM)"]]
# Out:
# item      代码       名称     现价 52周最低  52周最高      成交量 股息率(TTM) 股息(TTM)
# value  06823  香港电讯-SS  11.75  9.39  12.95  3017448     6.78   0.797
